# %%
# !pip install "polars[all]" -q

# %%
import polars as pl
df = pl.read_csv("transfers_*.csv",has_header=False)

# %%
df
# Out:
# shape: (3440, 5)
# ┌─────────────────────────┬─────────────────────────┬──────────┬────────────────────────┬──────────┐
# │ column_1                ┆ column_2                ┆ column_3 ┆ column_4               ┆ column_5 │
# │ ---                     ┆ ---                     ┆ ---      ┆ ---                    ┆ ---      │
# │ str                     ┆ str                     ┆ i64      ┆ str                    ┆ i64      │
# ╞═════════════════════════╪═════════════════════════╪══════════╪════════════════════════╪══════════╡
# │ azKuf123B0lUPODNSTKrvFA ┆ U3Jl4/oVyDnkRaSD6EKOLdY ┆ 4370     ┆ Gyn5FzvAdgcal7pj9iPT1y ┆ 211      │
# │ af28=                   ┆ n0Aw=                   ┆          ┆ 1TeJ10bMoI...          ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ cQeMvCCEp8gBQJ1JST7bqZz ┆ YiZEYmQ3Q35RAACDD2e7xuJ ┆ 89       ┆ 7t3LymAzv4xnZn0Ft55O8z ┆ 312      │
# ...
